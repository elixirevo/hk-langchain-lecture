# %% [markdown]
# # PowerPoint 프레젠테이션 로더
#
# Microsoft PowerPoint(`.pptx`, `.ppt`)는 프레젠테이션 제작에 가장 많이 사용되는 도구입니다.
#
# 이 노트북에서는 PowerPoint 파일에서 텍스트를 추출하여 LangChain Document로 변환하는 방법을 학습합니다.
#
# ## 주요 특징
#
# - 슬라이드별 텍스트 추출
# - 노트 영역 포함 가능
# - Elements 모드로 요소별 분리

# %% [markdown]
# # 06. PowerPoint 프레젠테이션 로더
#
# ## 학습 목표
# - `UnstructuredPowerPointLoader`로 `.pptx` 파일을 Document로 변환해요
# - 기본 모드와 Elements 모드(요소별 분리)의 차이를 이해해요
# - 슬라이드 텍스트를 RAG 시스템에서 활용하는 방법을 파악해요
#
# ## 사전 지식
# - 00-Document-Loader 노트북 완료
# - `pip install unstructured python-pptx` 설치
#
# ---
#
# > **RAG 파이프라인 위치**: Load 단계 — 프레젠테이션 자료도 `Document`로 변환해서 검색 가능하게 만들어요.

# %% [markdown]
# ## 환경 설정

# %%
from dotenv import load_dotenv

load_dotenv()

# 샘플 PowerPoint 파일 경로
FILE_PATH = "./data/sample.pptx"

# %% [markdown]
# ## UnstructuredPowerPointLoader
#
# `UnstructuredPowerPointLoader`는 PowerPoint 파일을 로드하는 표준 로더입니다.
#
# ### 특징
#
# - `.pptx` 및 `.ppt` 파일 지원
# - 슬라이드 텍스트 순서대로 추출
# - 노트 영역 텍스트 포함 가능
#
# ### 필요한 패키지
#
# ```bash
# pip install unstructured python-pptx
# ```

# %% [markdown]
# > ⚠️ **자주 하는 실수**: PowerPoint의 이미지, 차트, 도형 안에 있는 텍스트는 추출되지 않습니다. 시각 자료가 많은 발표 자료는 텍스트 추출 결과가 내용의 일부만 포함될 수 있습니다.

# %%
# ============================================================
# TODO: UnstructuredPowerPointLoader로 PowerPoint 파일을 로드해보세요
# 힌트: UnstructuredPowerPointLoader(FILE_PATH) → loader.load()
# 예상 결과: 로드된 문서 개수가 1개로 출력됩니다
# ============================================================

from langchain_community.document_loaders import UnstructuredPowerPointLoader

# 1단계: UnstructuredPowerPointLoader 생성
# - 기본 모드: 전체 슬라이드를 하나의 Document로 합쳐서 반환
loader = UnstructuredPowerPointLoader(FILE_PATH)

# 2단계: 문서 로드
docs = loader.load()

print(f"로드된 문서 개수: {len(docs)}")
print(f"\n첫 번째 문서의 타입: {type(docs[0])}")
# Out:
# 로드된 문서 개수: 1
#
# 첫 번째 문서의 타입: <class 'langchain_core.documents.base.Document'>

# %% [markdown]
# ### 문서 내용 확인

# %%
# 첫 번째 문서의 내용 출력 (처음 300자)
print("=" * 60)
print("📄 프레젠테이션 내용:")
print("=" * 60)
print(docs[0].page_content[:300])

print("\n" + "=" * 60)
print("🏷️  메타데이터:")
print("=" * 60)
print(docs[0].metadata)
# Out:
# ============================================================
# 📄 프레젠테이션 내용:
# ============================================================
# 청킹
#
# LangChain 튜토리얼 - Chapter 7
#
#
#
# 01
#
# CharacterTextSplitter
#
# 청킹 > CharacterTextSplitter
#
#
#
# CharacterTextSplitter
#
# 6-2. Chunking — 가장 기본적인 텍스트 분할
#
# 3
#
#
#
# 학습 목표
#
# 청킹(Chunking)이 RAG에서 왜 필요한지 이해한다
#
# CharacterTextSplitter의 단일 구분자 분할 방식을 익힌다
#
# chunk_size, chunk_overlap, separator 파라미터의 동작 원리를 파악한다
#
# 4
#
#
#
# RAG 파이
#
# ============================================================
# 🏷️  메타데이터:
# ============================================================
# {'source': './data/sample.pptx'}

# %% [markdown]
# ---
#
# > **섹션 전환** — 기본 모드는 전체 슬라이드를 하나로 합쳐요. 슬라이드별로 분리하고 싶다면 아래의 `elements` 모드를 사용해 보세요.

# %% [markdown]
# > 🎯 **강의 포인트**: 강의 슬라이드나 발표 자료를 RAG로 활용할 때, 기본 모드는 전체를 하나의 Document로 합쳐서 검색 정밀도가 낮습니다. `mode="elements"`로 슬라이드별 분리를 권장합니다.

# %% [markdown]
# > 💡 **실무 팁**: `metadata["page_number"]`와 `metadata["category"]`를 함께 활용하면 "몇 번째 슬라이드의 어떤 요소인지"를 정확히 추적할 수 있습니다. 이 정보를 LLM 응답에 포함시켜 출처를 명시할 수 있습니다.

# %% [markdown]
# ## 핵심 정리 및 마무리
#
# ### 모드 선택 가이드
#
# | 상황 | 추천 모드 |
# |------|----------|
# | 전체 내용을 한 번에 처리 | 기본 모드 |
# | 슬라이드별 분석 필요 | `mode="elements"` |
# | 제목/본문 구분이 필요 | `mode="elements"` |
# | 간단한 텍스트 추출 | 기본 모드 |
#
# ### 주의 사항
# > 이미지, 차트, 도형 안에 있는 텍스트는 추출되지 않아요. 시각 자료가 많은 프레젠테이션은 텍스트 추출 결과가 불완전할 수 있어요.
#
# ---
#
# ## 다음 예고
#
# 다음은 웹 페이지 콘텐츠를 불러오는 방법을 배워볼게요.
#
# - **07-WebBase-Loader**: URL에서 직접 콘텐츠 로딩
# - **08-TXT-Loader**: 텍스트 파일과 인코딩 처리

# %%
# ============================================================
# TODO: mode="elements"로 PowerPoint를 요소별로 로드해보세요
# 힌트: UnstructuredPowerPointLoader(FILE_PATH, mode="elements")
# 예상 결과: 17개의 Document가 생성되고 각 요소의 category 메타데이터가 포함됩니다
# ============================================================

# 1단계: elements 모드로 로더 생성
# - mode="elements": 제목, 본문 등 각 요소를 별도 Document로 분리
# - 각 Document의 metadata에 category 정보 저장 (Title, NarrativeText 등)
loader = UnstructuredPowerPointLoader(FILE_PATH, mode="elements")

# 2단계: 문서 로드
docs = loader.load()

print(f"Elements 모드 문서 개수: {len(docs)}")
print(f"\n처음 3개 요소:")
for i, doc in enumerate(docs[:3]):
    print(f"\n[요소 {i}]")
    print(f"내용: {doc.page_content[:100]}...")
    print(f"메타데이터: {doc.metadata}")
# Out:
# Elements 모드 문서 개수: 803
#
# 처음 3개 요소:
#
# [요소 0]
# 내용: 청킹...
# 메타데이터: {'source': './data/sample.pptx', 'category_depth': 1, 'file_directory': './data', 'filename': 'sample.pptx', 'last_modified': '2026-04-02T14:38:30', 'page_number': 1, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation', 'category': 'Title', 'element_id': '6095e9e3ad571316493d080b15d9e9b3'}
#
# [요소 1]
# 내용: LangChain 튜토리얼 - Chapter 7...
# 메타데이터: {'source': './data/sample.pptx', 'category_depth': 1, 'file_directory': './data', 'filename': 'sample.pptx', 'last_modified': '2026-04-02T14:38:30', 'page_number': 1, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation', 'category': 'Title', 'element_id': '75df75dd1b9b8d3de32f0146daba54e3'}
#
# [요소 2]
# 내용: ...
# 메타데이터: {'source': './data/sample.pptx', 'last_modified': '2026-04-02T14:38:30', 'page_number': 1, 'languages': ['eng'], 'file_directory': './data', 'filename': 'sample.pptx', 'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation', 'category': 'PageBreak', 'element_id': '8d43eb7601d9fc652119bf340d91e000'}
